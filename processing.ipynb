# %%
import os
from glob import glob
import json

# %%
os.listdir("output")
# Out:
# ['.DS_Store', 'step.geojson.zip', 'step.geojson', 'shelter_data.json']

# %%
with open("output/shelter_data.json", "r") as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['death_json_counter', 'shelter_agent_types', 'shelter_json_counter'])

# %%
shelter_data = data['shelter_agent_types']

# %%
shelter_data_counter = data['shelter_json_counter']

# %%
shelter_data_counter
# Out:
# [{'shelter_10_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_11_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_12_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_1_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_2_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_3_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_4_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_5_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_6_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_7_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_8_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0},
#   'shelter_9_0': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0}},
#  {'shelter_10_30': {'adult': 6, 'child': 0, 'elder': 0, 'teen': 1},
#   'shelter_11_30': {'adult': 5, 'child': 1, 'elder': 0, 'teen': 1},
# ...

# %%
shelter_data
# Out:
# {'shelter_1': {'adult': 228, 'child': 19, 'elder': 57, 'teen': 43},
#  'shelter_10': {'adult': 518, 'child': 61, 'elder': 181, 'teen': 109},
#  'shelter_11': {'adult': 136, 'child': 10, 'elder': 44, 'teen': 28},
#  'shelter_12': {'adult': 820, 'child': 74, 'elder': 265, 'teen': 161},
#  'shelter_2': {'adult': 418, 'child': 35, 'elder': 136, 'teen': 98},
#  'shelter_3': {'adult': 21, 'child': 4, 'elder': 12, 'teen': 6},
#  'shelter_4': {'adult': 313, 'child': 35, 'elder': 101, 'teen': 81},
#  'shelter_5': {'adult': 59, 'child': 9, 'elder': 32, 'teen': 17},
#  'shelter_6': {'adult': 860, 'child': 93, 'elder': 256, 'teen': 191},
#  'shelter_7': {'adult': 970, 'child': 99, 'elder': 206, 'teen': 202},
#  'shelter_8': {'adult': 760, 'child': 110, 'elder': 160, 'teen': 164},
#  'shelter_9': {'adult': 219, 'child': 12, 'elder': 73, 'teen': 44}}

# %%
total_person = sum([sum(shelter_data[shelter].values()) for shelter in shelter_data])
print(f"Total person in shelter: {total_person}")
# Out:
# Total person in shelter: 8484

# %%
death_counter = data['death_json_counter']

# %%
death_counter
# Out:
# [{'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 0},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 30},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 60},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 90},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 120},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 150},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 180},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 210},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 240},
#  {'dead_agents': {'adult': 0, 'child': 0, 'elder': 0, 'teen': 0, 'total': 0},
#   'step': 270},
# ...

# %%
sum(death_counter[-1]['dead_agents'].values())
# Out:
# 9826

# %%
death_counter[-1]['dead_agents']
# Out:
# {'adult': 1191, 'child': 1173, 'elder': 1350, 'teen': 1199, 'total': 4913}

# %%
token = "yh3mKp4RRL7zrMdIUh6cRlWIB2WnGOxU"
scenario_id = "7b183c40-6db5-473e-bf7c-dc4295cb22ef"

# %%
a = f"Bearer {token}"
a
# Out:
# 'Bearer yh3mKp4RRL7zrMdIUh6cRlWIB2WnGOxU'

# %%
# Define the payload (data to send)
payload = {
    'step': None, 
    'shelter': None, 
    'scenario': None, 
    'shelter_agents_child': None, 
    'shelter_agents_teen': None, 
    'shelter_agents_adult': None, 
    'shelter_agents_elder': None, 
    'total_agents_in_shelter': None
}

import requests

# Define the API URL
url = "https://mhews.geodashboard.io/panel/items/shelter_data_perstep"  # Replace with the actual API endpoint


# Define headers (if needed)
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}"  # If the API requires authentication
}

# Send POST request
response = requests.post(url, json=payload, headers=headers)

# Print response
print("Status Code:", response.status_code)
print("Response JSON:", response.json())  # Assuming the response is in JSON format
# Out:
# Status Code: 200
# Response JSON: {'data': {'id': 1, 'user_created': '6ab60507-a441-4cf8-b4cb-69436264a95b', 'date_created': '2025-02-25T08:54:48.624Z', 'user_updated': None, 'date_updated': None, 'step': None, 'shelter': None, 'scenario': None, 'shelter_agents_child': None, 'shelter_agents_teen': None, 'shelter_agents_adult': None, 'shelter_agents_elder': None, 'total_agents_in_shelter': None}}

# %%
# TES PACITAN
# id	nama	tipe	lokasi	lon	lat	keterangan
# 2001	Tamperan	TEA	Sidoharjo	111,072969433712	-8,2248317905863	Eksisting
# 2002	Gudang kosong	TES	Sidoharjo	111,074410653414	-8,21189206351928	Eksisting
# 2003	Kandang Sapi	TES	Sidoharjo	111,07289885295	-8,21253466670716	Eksisting
# 2004	ngelowo endah	TES	Kembang	111,116512764252	-8,22188454997049	Eksisting
# 2005	Watu Gupit Sedayu	TES	Kembang	111,122085286268	-8,22003484677068	Eksisting
# 2006	Kepangrono	TEA	Kembang	111,11894439774	-8,22060591741208	Eksisting
# 2007	STKIP PGRI PACITAN	TES	Ploso	111,100745630997	-8,20587484486217	Rekomendasi
# 2008	Bukit Giri Sampurno	TES	Ploso	111,108413761349	-8,19014668692899	Eksisting
# 2009	Mesjid Nurul huda	TEA	Sidoharjo	111,069703785076	-8,19208234932716	Eksisting
# 2010	Mesjid An-Nemah Bungursari	TEA	Sidoharjo	111,083648839864	-8,19275159635365	Eksisting
# 2011	Musola Alfalaq Sumberharjo	TEA	Sidoharjo	111,08697635605	-8,18664191977908	Eksisting
# 2012	Pasar Gerdon	TEA	Sidoharjo	111,099443767973	-8,18873631902589	Eksisting

import pandas as pd
df_tes = pd.read_csv("data_pacitan/TEA_TES_PACITAN.csv", delimiter=";")
df_tes.head()
# Out:
#        id               nama tipe     lokasi               lon  \
# 0  2001.0           Tamperan  TEA  Sidoharjo  111,072969433712
# 1  2002.0      Gudang kosong  TES  Sidoharjo  111,074410653414
# 2  2003.0       Kandang Sapi  TES  Sidoharjo   111,07289885295
# 3  2004.0      ngelowo endah  TES    Kembang  111,116512764252
# 4  2005.0  Watu Gupit Sedayu  TES    Kembang  111,122085286268
#
#                  lat keterangan
# 0   -8,2248317905863  Eksisting
# 1  -8,21189206351928  Eksisting
# 2  -8,21253466670716  Eksisting
# 3  -8,22188454997049  Eksisting
# 4  -8,22003484677068  Eksisting

# %%
df_tes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          12 non-null     float64
#  1   nama        12 non-null     object
#  2   tipe        12 non-null     object
#  3   lokasi      12 non-null     object
#  4   lon         12 non-null     object
#  5   lat         12 non-null     object
#  6   keterangan  12 non-null     object
#  7   idx         12 non-null     float64
# dtypes: float64(2), object(6)
# memory usage: 960.0+ bytes

# %%
df_tes["idx"] = df_tes["id"].astype(str).str.split(".").str[0]
df_tes.head()
# Out:
#        id               nama tipe     lokasi               lon  \
# 0  2001.0           Tamperan  TEA  Sidoharjo  111,072969433712
# 1  2002.0      Gudang kosong  TES  Sidoharjo  111,074410653414
# 2  2003.0       Kandang Sapi  TES  Sidoharjo   111,07289885295
# 3  2004.0      ngelowo endah  TES    Kembang  111,116512764252
# 4  2005.0  Watu Gupit Sedayu  TES    Kembang  111,122085286268
#
#                  lat keterangan   idx
# 0   -8,2248317905863  Eksisting  2001
# 1  -8,21189206351928  Eksisting  2002
# 2  -8,21253466670716  Eksisting  2003
# 3  -8,22188454997049  Eksisting  2004
# 4  -8,22003484677068  Eksisting  2005

# %%
df_tes["idx_real"] = df_tes["idx"].astype(str).str[-2:]
df_tes
# Out:
#         id                        nama tipe     lokasi               lon  \
# 0   2001.0                    Tamperan  TEA  Sidoharjo  111,072969433712
# 1   2002.0               Gudang kosong  TES  Sidoharjo  111,074410653414
# 2   2003.0                Kandang Sapi  TES  Sidoharjo   111,07289885295
# 3   2004.0               ngelowo endah  TES    Kembang  111,116512764252
# 4   2005.0           Watu Gupit Sedayu  TES    Kembang  111,122085286268
# 5   2006.0                  Kepangrono  TEA    Kembang   111,11894439774
# 6   2007.0          STKIP PGRI PACITAN  TES      Ploso  111,100745630997
# 7   2008.0         Bukit Giri Sampurno  TES      Ploso  111,108413761349
# 8   2009.0           Mesjid Nurul huda  TEA  Sidoharjo  111,069703785076
# 9   2010.0  Mesjid An-Nemah Bungursari  TEA  Sidoharjo  111,083648839864
# 10  2011.0  Musola Alfalaq Sumberharjo  TEA  Sidoharjo   111,08697635605
# 11  2012.0                Pasar Gerdon  TEA  Sidoharjo  111,099443767973
# ...

# %%
df_tes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          12 non-null     float64
#  1   nama        12 non-null     object
#  2   tipe        12 non-null     object
#  3   lokasi      12 non-null     object
#  4   lon         12 non-null     object
#  5   lat         12 non-null     object
#  6   keterangan  12 non-null     object
#  7   idx         13 non-null     object
#  8   idx_real    13 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 1.0+ KB

# %%
nama_shelter = df_tes[df_tes["idx_real"] == "10"]["nama"].iloc[0]
print(nama_shelter)
# Out:
# Mesjid An-Nemah Bungursari

# %%
url = "https://mhews.geodashboard.io/panel/items/shelter_data_perstep"

# %%
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}"  # If the API requires authentication
}
headers
# Out:
# {'Content-Type': 'application/json',
#  'Authorization': 'Bearer yh3mKp4RRL7zrMdIUh6cRlWIB2WnGOxU'}

# %%
error = []
for item in shelter_data_counter:
    # print(item)
    keys = list(item.keys())
    # print(keys)
    
    for key in keys:
        shelter_number = key.split("_")[1]
        
        shelter_number = shelter_number if len(shelter_number) == 2 else "0" + shelter_number
        
        step = key.split("_")[2]
        
        shelter_agents_child = item[key]['child']
        shelter_agents_teen = item[key]['teen']
        shelter_agents_adult = item[key]['adult']
        shelter_agents_elder = item[key]['elder']
        total = shelter_agents_child + shelter_agents_teen + shelter_agents_adult + shelter_agents_elder
        
        print(shelter_number)
        
        nama_shelter = df_tes[df_tes["idx_real"] == shelter_number]['nama'].iloc[0]
        
        payload = {
                'step': step, 
                'shelter': nama_shelter, 
                'scenario': scenario_id, 
                'shelter_agents_child': shelter_agents_child, 
                'shelter_agents_teen': shelter_agents_teen, 
                'shelter_agents_adult': shelter_agents_adult, 
                'shelter_agents_elder': shelter_agents_elder, 
                'total_agents_in_shelter': total
            }
        
        print(payload)
        # print(shelter_number, step)
        
        try:
            response = requests.post(url, json=payload, headers=headers)
            print("Status Code:", response.status_code)
            print("Response JSON:", response.json()) 
        except Exception as e:
            error.append({
                "payload" : payload,
                "error": str(e)
            })
# Out:
# 10
# {'step': '0', 'shelter': 'Mesjid An-Nemah Bungursari', 'scenario': '7b183c40-6db5-473e-bf7c-dc4295cb22ef', 'shelter_agents_child': 0, 'shelter_agents_teen': 0, 'shelter_agents_adult': 0, 'shelter_agents_elder': 0, 'total_agents_in_shelter': 0}
# Status Code: 200
# Response JSON: {'data': {'id': 14, 'user_created': '6ab60507-a441-4cf8-b4cb-69436264a95b', 'date_created': '2025-02-25T10:28:45.163Z', 'user_updated': None, 'date_updated': None, 'step': 0, 'shelter': 'Mesjid An-Nemah Bungursari', 'scenario': '7b183c40-6db5-473e-bf7c-dc4295cb22ef', 'shelter_agents_child': 0, 'shelter_agents_teen': 0, 'shelter_agents_adult': 0, 'shelter_agents_elder': 0, 'total_agents_in_shelter': 0}}
# 11
# {'step': '0', 'shelter': 'Musola Alfalaq Sumberharjo', 'scenario': '7b183c40-6db5-473e-bf7c-dc4295cb22ef', 'shelter_agents_child': 0, 'shelter_agents_teen': 0, 'shelter_agents_adult': 0, 'shelter_agents_elder': 0, 'total_agents_in_shelter': 0}
# Status Code: 200
# ...

# %%
len(error)
# Out:
# 0

# %%
url = "https://mhews.geodashboard.io/panel/items/death_data_perstep"  # Replace with the actual API endpoint


# Define headers (if needed)
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}"  # If the API requires authentication
}

error = []
for item in death_counter:
    # print(item)
    # keys = list(item.keys())
    # print(keys)
    step = item['step']
    dead_agents = item['dead_agents']
    
    dead_agents_child = dead_agents['child']
    dead_agents_teen = dead_agents['teen']
    dead_agents_adult = dead_agents['adult']
    dead_agents_elder = dead_agents['elder']
    total = dead_agents['total']
    
    payload = {
                'step': step, 
                'scenario': scenario_id, 
                'dead_agents_child': dead_agents_child, 
                'dead_agents_teen': dead_agents_teen, 
                'dead_agents_adult': dead_agents_adult, 
                'dead_agents_elder': dead_agents_elder, 
                'total_dead_agents': total
            }
        
    try:
        response = requests.post(url, json=payload, headers=headers)
        print("Status Code:", response.status_code)
        print("Response JSON:", response.json()) 
    except Exception as e:
        error.append({
            "payload" : payload,
            "error": str(e)
        })
# Out:
# Status Code: 200
# Response JSON: {'data': {'id': 2, 'date_created': '2025-02-25T10:46:42.745Z', 'user_updated': None, 'date_updated': None, 'step': 0, 'dead_agents_child': 0, 'dead_agents_adult': 0, 'dead_agents_elder': 0, 'dead_agents_teen': 0, 'total_dead_agents': 0, 'scenario': '7b183c40-6db5-473e-bf7c-dc4295cb22ef'}}
# Status Code: 200
# Response JSON: {'data': {'id': 3, 'date_created': '2025-02-25T10:46:43.080Z', 'user_updated': None, 'date_updated': None, 'step': 30, 'dead_agents_child': 0, 'dead_agents_adult': 0, 'dead_agents_elder': 0, 'dead_agents_teen': 0, 'total_dead_agents': 0, 'scenario': '7b183c40-6db5-473e-bf7c-dc4295cb22ef'}}
# Status Code: 200
# Response JSON: {'data': {'id': 4, 'date_created': '2025-02-25T10:46:43.350Z', 'user_updated': None, 'date_updated': None, 'step': 60, 'dead_agents_child': 0, 'dead_agents_adult': 0, 'dead_agents_elder': 0, 'dead_agents_teen': 0, 'total_dead_agents': 0, 'scenario': '7b183c40-6db5-473e-bf7c-dc4295cb22ef'}}
# Status Code: 200
# ...

# %%
# Define the payload (data to send)
payload = {
    'step': None, 
    'shelter': None, 
    'scenario': None, 
    'shelter_agents_child': None, 
    'shelter_agents_teen': None, 
    'shelter_agents_adult': None, 
    'shelter_agents_elder': None, 
    'total_agents_in_shelter': None
}

import requests

# Define the API URL
url = "https://mhews.geodashboard.io/panel/items/shelter_data_perstep"  # Replace with the actual API endpoint


# Define headers (if needed)
headers = {
    "Content-Type": "application/json",
    "Authorization": f"Bearer {token}"  # If the API requires authentication
}

# Send POST request
response = requests.post(url, json=payload, headers=headers)

# Print response
print("Status Code:", response.status_code)
print("Response JSON:", response.json())
